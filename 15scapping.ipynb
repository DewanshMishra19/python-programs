# %%
from dputils.scrape import Tag, Scraper

# %% [markdown]
# Tag class helps to decide what to collect from the page.
# Scrapers excecutes the scrapping progress.

# %%
url="https://www.amazon.in/s?k=laptops%27&i=computers&adgrpid=140360389887&hvadid=598082394866&hvdev=c&hvlocphy=9302767&hvnetw=g&hvqmt=e&hvrand=4979110353989632006&hvtargid=kwd-667380588451&hydadcr=14216_2276704&tag=googinhydr1-21&ref=pd_sl_5dbix2qo6r_e"

# %%
amazon=Scraper(url)
# Out:
# Selecting a random User-Agent...
# Randomly picked browser: Firefox
# Randomly picked operating system: Windows
# 🌐🌐🌐🌐🌐🌐🌐🌐🌐🌐
# User agent:  {'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64; rv:94.0) Gecko/20100101 Firefox/94.0'}
# Cookies:  {'session-id': '', 'session-id-time': '', 'session-token': ''}
# url:  https://www.amazon.in/s?k=laptops%27&i=computers&adgrpid=140360389887&hvadid=598082394866&hvdev=c&hvlocphy=9302767&hvnetw=g&hvqmt=e&hvrand=4979110353989632006&hvtargid=kwd-667380588451&hydadcr=14216_2276704&tag=googinhydr1-21&ref=pd_sl_5dbix2qo6r_e
# 🌐🌐🌐🌐🌐🌐🌐🌐🌐🌐

# %%
target = Tag(cls = 's-main-slot s-result-list s-search-results sg-row')
items = Tag(cls = 's-result-item')
title = Tag('h2', cls="a-size-mini a-spacing-none a-color-base s-line-clamp-2")
price = Tag('span', cls="a-price")

# %%
result=amazon.get_repeating_page_data(target, items,heading=title, price=price)

# %%
import pandas as pd
import numpy as np

# %%
df=pd.DataFrame(result)
df
# Out:
#                                               heading           price
# 0                                                None            None
# 1                                                None            None
# 2   Acer Aspire Lite 12th Gen Intel Core i5-1235U ...  ₹43,999₹43,999
# 3   Acer [Smartchoice] Aspire Lite AMD Ryzen 3 530...  ₹28,999₹28,999
# 4   (Refurbished) Lenovo ThinkPad 6th Gen Intel Co...  ₹17,249₹17,249
# 5   Lenovo V15 Intel Celeron N4500 15.6" (39.62 cm...  ₹21,990₹21,990
# 6   ASUS VivoBook 15 (2021) Thin and Light Laptop,...  ₹19,990₹19,990
# 7                                                None  ₹48,790₹48,790
# 8                                                None  ₹48,790₹48,790
# 9                                                None  ₹38,990₹38,990
# 10                                               None  ₹41,990₹41,990
# 11                                               None  ₹53,327₹53,327
# 12                                               None            None
# 13  (Refurbished) Lenovo ThinkPad 5th Gen Intel Co...  ₹14,999₹14,999
# 14  (Refurbished) HP Chromebook 13 G1 6th Gen Inte...  ₹12,999₹12,999
# 15  HP Laptop 15s, AMD Ryzen 3 5300U, 15.6-inch (3...  ₹31,990₹31,990
# 16  HP Laptop 15s, 12th Gen Intel Core i5-1235U, 1...  ₹52,990₹52,990
# 17  HP Pavilion 14, 12th Gen Intel Core i5-1235U, ...  ₹61,780₹61,780
# 18  Lenovo IdeaPad 1 AMD Ryzen 5 5500U 15.6" HD Th...  ₹38,990₹38,990
# 19                                               None  ₹16,990₹16,990
# 20                                               None            None
# 21  Chuwi HeroBook Pro 14.1'' Intel Celeron N4020 ...  ₹16,990₹16,990
# 22  (Refurbished) Lenovo ThinkPad 7th Gen Intel Co...  ₹15,640₹15,640
# 23  (Refurbished) HP C640 10th Gen Intel Core i5 T...  ₹17,499₹17,499
# 24  Chuwi HeroBook Pro 14.1'' Intel Celeron N4020 ...  ₹16,990₹16,990
# 25  Dell 15 Thin & Light Laptop, 12th Gen Intel Co...  ₹47,123₹47,123
# 26  Dell 15 Thin & Light Laptop, 12th Gen Intel Co...  ₹47,123₹47,123
# 27  HP Laptop 15,12th Gen Intel Core i3-1215U,15.6...  ₹36,970₹36,970
# 28  HP Laptop 15s, 11th Gen Intel Core i3-1115G4, ...  ₹33,990₹33,990
# 29  Acer [Smartchoice] Aspire Lite AMD Ryzen 3 530...  ₹28,999₹28,999
# 30  (Refurbished) HP C640 10th Gen Intel Core i5 T...  ₹19,499₹19,499
# 31  Dell 15 Thin & Light Laptop, Intel Core i5-123...  ₹49,990₹49,990
# 32  Lenovo V15 Intel Celeron N4500 15.6" (39.62 cm...  ₹18,990₹18,990
# 33  ASUS Vivobook 14, Intel Core i3-1115G4 11th Ge...  ₹30,990₹30,990
# 34  HONOR MagicBook X16 (2024), 12th Gen Intel Cor...  ₹45,990₹45,990
# 35  Dell Inspiron 7420 2in1 Laptop, Intel Core i7-...  ₹77,490₹77,490
# 36  HP C640 10th Gen Intel Core i5 Thin & Light To...  ₹26,999₹26,999
# 37  HP Laptop 15s, Intel Celeron, 15.6-inch (39.6 ...  ₹29,490₹29,490
# 38  ASUS TUF F15 Gaming Laptop, Intel Core i5-1140...  ₹54,990₹54,990
# 39  Primebook S 4G Android Based MediaTek MT8788 -...  ₹15,990₹15,990
# 40                                               None    ₹1,499₹1,499
# 41                                               None            None
# 42                                               None            None
# 43                                               None            None
# 44                                               None            None

# %%
print(df.columns.tolist())
# Out:
# ['heading', 'price']

# %%
def clean_price_column(price):
    if isinstance(price,str):     #check if price is string or not
        price=price.replace(',','')
        price=price.strip()   # to remove whitespace
        if price.isnumeric():
            price=int(price)  #typecasting
            return price
        if len(price)==4:
            return np.nan     #NaN is not a number
            return price

# %%
clean_price_column('43,999')
# Out:
# 43999

# %%
df['cleaned_price']=df['price'].apply(clean_price_column)
df
# Out:
#                                               heading           price  \
# 0                                                None            None
# 1                                                None            None
# 2   Acer Aspire Lite 12th Gen Intel Core i5-1235U ...  ₹43,999₹43,999
# 3   Acer [Smartchoice] Aspire Lite AMD Ryzen 3 530...  ₹28,999₹28,999
# 4   (Refurbished) Lenovo ThinkPad 6th Gen Intel Co...  ₹17,249₹17,249
# 5   Lenovo V15 Intel Celeron N4500 15.6" (39.62 cm...  ₹21,990₹21,990
# 6   ASUS VivoBook 15 (2021) Thin and Light Laptop,...  ₹19,990₹19,990
# 7                                                None  ₹48,790₹48,790
# 8                                                None  ₹48,790₹48,790
# 9                                                None  ₹38,990₹38,990
# 10                                               None  ₹41,990₹41,990
# 11                                               None  ₹53,327₹53,327
# 12                                               None            None
# 13  (Refurbished) Lenovo ThinkPad 5th Gen Intel Co...  ₹14,999₹14,999
# 14  (Refurbished) HP Chromebook 13 G1 6th Gen Inte...  ₹12,999₹12,999
# 15  HP Laptop 15s, AMD Ryzen 3 5300U, 15.6-inch (3...  ₹31,990₹31,990
# 16  HP Laptop 15s, 12th Gen Intel Core i5-1235U, 1...  ₹52,990₹52,990
# 17  HP Pavilion 14, 12th Gen Intel Core i5-1235U, ...  ₹61,780₹61,780
# 18  Lenovo IdeaPad 1 AMD Ryzen 5 5500U 15.6" HD Th...  ₹38,990₹38,990
# 19                                               None  ₹16,990₹16,990
# 20                                               None            None
# 21  Chuwi HeroBook Pro 14.1'' Intel Celeron N4020 ...  ₹16,990₹16,990
# 22  (Refurbished) Lenovo ThinkPad 7th Gen Intel Co...  ₹15,640₹15,640
# 23  (Refurbished) HP C640 10th Gen Intel Core i5 T...  ₹17,499₹17,499
# 24  Chuwi HeroBook Pro 14.1'' Intel Celeron N4020 ...  ₹16,990₹16,990
# 25  Dell 15 Thin & Light Laptop, 12th Gen Intel Co...  ₹47,123₹47,123
# 26  Dell 15 Thin & Light Laptop, 12th Gen Intel Co...  ₹47,123₹47,123
# 27  HP Laptop 15,12th Gen Intel Core i3-1215U,15.6...  ₹36,970₹36,970
# 28  HP Laptop 15s, 11th Gen Intel Core i3-1115G4, ...  ₹33,990₹33,990
# 29  Acer [Smartchoice] Aspire Lite AMD Ryzen 3 530...  ₹28,999₹28,999
# 30  (Refurbished) HP C640 10th Gen Intel Core i5 T...  ₹19,499₹19,499
# 31  Dell 15 Thin & Light Laptop, Intel Core i5-123...  ₹49,990₹49,990
# 32  Lenovo V15 Intel Celeron N4500 15.6" (39.62 cm...  ₹18,990₹18,990
# 33  ASUS Vivobook 14, Intel Core i3-1115G4 11th Ge...  ₹30,990₹30,990
# 34  HONOR MagicBook X16 (2024), 12th Gen Intel Cor...  ₹45,990₹45,990
# 35  Dell Inspiron 7420 2in1 Laptop, Intel Core i7-...  ₹77,490₹77,490
# 36  HP C640 10th Gen Intel Core i5 Thin & Light To...  ₹26,999₹26,999
# 37  HP Laptop 15s, Intel Celeron, 15.6-inch (39.6 ...  ₹29,490₹29,490
# 38  ASUS TUF F15 Gaming Laptop, Intel Core i5-1140...  ₹54,990₹54,990
# 39  Primebook S 4G Android Based MediaTek MT8788 -...  ₹15,990₹15,990
# 40                                               None    ₹1,499₹1,499
# 41                                               None            None
# 42                                               None            None
# 43                                               None            None
# 44                                               None            None
#
#    cleaned_price
# 0           None
# 1           None
# 2           None
# 3           None
# 4           None
# 5           None
# 6           None
# 7           None
# 8           None
# 9           None
# 10          None
# 11          None
# 12          None
# 13          None
# 14          None
# 15          None
# 16          None
# 17          None
# 18          None
# 19          None
# 20          None
# 21          None
# 22          None
# 23          None
# 24          None
# 25          None
# 26          None
# 27          None
# 28          None
# 29          None
# 30          None
# 31          None
# 32          None
# 33          None
# 34          None
# 35          None
# 36          None
# 37          None
# 38          None
# 39          None
# 40          None
# 41          None
# 42          None
# 43          None
# 44          None
